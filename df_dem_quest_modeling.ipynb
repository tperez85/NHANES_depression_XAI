# %% [markdown]
# # TFG - Comprendiendo la depresión a traves de XAI
# Tamara Pérez Pérez
#
#
#
# ## Table of contents<a class="anchor" id="index"></a>

# %% [markdown]
# [Modeling Data: Demographic and Questionnaire Dataset](#modeling-data)
# * [Imports](#imports)
# * [Demographic Dataset](#dataset)
#    * [Decision Tree Classifier](#dtree)
#    * [Explainable Boosting Classifier](#ebm)
#    * [Random Forest](#rf)
#        * [SHAP](#shap)
#        * [LIME](#lime)

# %% [markdown]
# ## Modeling Data: Demographic and Questionnaire Dataset<a class="anchor" id="modeling-data"></a>

# %% [markdown]
# ### Imports<a class="anchor" id="imports"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_recall_curve
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree
from interpret.glassbox import (LogisticRegression,
                                ClassificationTree,
                                ExplainableBoostingClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from interpret.blackbox import LimeTabular
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss, TomekLinks
from imblearn.combine import SMOTETomek
from interpret import show
import shap
# %matplotlib inline
# %run functions.ipynb

# %% [markdown]
# Read the CSV file into a DataFrame and select relevant features for analysis.
# Preprocess binary responses, perform one-hot encoding on object columns, and display the head of the resulting DataFrame.

# %%
df = pd.read_csv('../csv/df.csv',index_col=0)
features = ['gender',
 'age',
 'race',
 'education_level',
 'marital_status',
 'people_in_the_household',
 'annual_household_income',
 'citizenship_status',
 'total_cholesterol',
            'BMI',
 'alcohol_lifetime',
 'binge_drinking_lifetime',
 'number_drinks_last_year',
 'age_started_smoking',
 'smoke_lifetime',
 'number_cigarettes_last_month',
 'hours_sleep',
 'trouble_sleeping_history',
 'minutes_sedentary_activity',
 'physical_activity_level',
            'depression_status']
df_dem_quest = select_features(df, features)
df_dem_quest = preprocess_binary_responses(df_dem_quest)
df_dem_quest = one_hot_encode_object_columns(df_dem_quest)
df_dem_quest.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5372 entries, 73557 to 83727
# Data columns (total 42 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        5372 non-null   int64
#  1   people_in_the_household                    5372 non-null   int64
#  2   annual_household_income                    5372 non-null   int64
#  3   total_cholesterol                          5372 non-null   float64
#  4   BMI                                        5372 non-null   float64
#  5   alcohol_lifetime                           5372 non-null   int64
#  6   binge_drinking_lifetime                    5372 non-null   int64
#  7   number_drinks_last_year                    5372 non-null   int64
#  8   age_started_smoking                        5372 non-null   int64
#  9   smoke_lifetime                             5372 non-null   int64
#  10  number_cigarettes_last_month               5372 non-null   float64
#  11  hours_sleep                                5372 non-null   int64
#  12  trouble_sleeping_history                   5372 non-null   int64
#  13  minutes_sedentary_activity                 5372 non-null   int64
#  14  depression_status                          5372 non-null   int64
#  15  citizenship_status_citizen                 5372 non-null   uint8
#  16  citizenship_status_not_citizen             5372 non-null   uint8
#  17  citizenship_status_unknown                 5372 non-null   uint8
#  18  education_level_9-11th_grade               5372 non-null   uint8
#  19  education_level_college_graduate           5372 non-null   uint8
#  20  education_level_high_school                5372 non-null   uint8
#  21  education_level_less_than_9th_grade        5372 non-null   uint8
#  22  education_level_some_college               5372 non-null   uint8
#  23  education_level_unknown                    5372 non-null   uint8
#  24  gender_female                              5372 non-null   uint8
#  25  gender_male                                5372 non-null   uint8
#  26  marital_status_divorced                    5372 non-null   uint8
#  27  marital_status_living_with_partner         5372 non-null   uint8
#  28  marital_status_married                     5372 non-null   uint8
#  29  marital_status_never_married               5372 non-null   uint8
#  30  marital_status_separated                   5372 non-null   uint8
#  31  marital_status_unknown                     5372 non-null   uint8
#  32  marital_status_widowed                     5372 non-null   uint8
#  33  physical_activity_level_active             5372 non-null   uint8
#  34  physical_activity_level_moderately_active  5372 non-null   uint8
#  35  physical_activity_level_sedentary          5372 non-null   uint8
#  36  race_asian                                 5372 non-null   uint8
#  37  race_black                                 5372 non-null   uint8
#  38  race_hispanic                              5372 non-null   uint8
#  39  race_mexican                               5372 non-null   uint8
#  40  race_other_race                            5372 non-null   uint8
#  41  race_white                                 5372 non-null   uint8
# dtypes: float64(3), int64(12), uint8(27)
# memory usage: 813.1 KB
#        age  people_in_the_household  annual_household_income  \
# SEQN
# 73557   69                        3                        4
# 73558   54                        4                        7
# 73559   72                        2                       10
# 73561   73                        2                       12
# 73562   56                        1                        9
#
#        total_cholesterol   BMI  alcohol_lifetime  binge_drinking_lifetime  \
# SEQN
# 73557              167.0  26.7                 1                        1
# 73558              170.0  28.6                 1                        1
# 73559              126.0  28.9                 1                        0
# 73561              201.0  19.7                 1                        0
# 73562              226.0  41.7                 1                        0
#
#        number_drinks_last_year  age_started_smoking  smoke_lifetime  ...  \
# SEQN                                                                 ...
# 73557                        3                   17               1  ...
# 73558                        7                    0               1  ...
# 73559                        0                   20               1  ...
# 73561                        0                    0               0  ...
# 73562                       15                   18               1  ...
#
#        marital_status_widowed  physical_activity_level_active  \
# SEQN
# 73557                       0                               0
# 73558                       0                               0
# 73559                       0                               0
# 73561                       0                               0
# 73562                       0                               1
#
#        physical_activity_level_moderately_active  \
# SEQN
# 73557                                          0
# 73558                                          1
# 73559                                          1
# 73561                                          1
# 73562                                          0
#
#        physical_activity_level_sedentary  race_asian  race_black  \
# SEQN
# 73557                                  1           0           1
# 73558                                  0           0           0
# 73559                                  0           0           0
# 73561                                  0           0           0
# 73562                                  0           0           0
#
#        race_hispanic  race_mexican  race_other_race  race_white
# SEQN
# 73557              0             0                0           0
# 73558              0             0                0           1
# 73559              0             0                0           1
# 73561              0             0                0           1
# 73562              0             1                0           0
#
# [5 rows x 42 columns]

# %% [markdown]
# Split the dataset into training and testing sets using an 80-20 split

# %%
X_train, X_test, y_train, y_test = split_data(df_dem_quest, target_column='depression_status', test_size=0.2, random_state=42)

# %% [markdown]
# ### Decision Tree Classifier<a class="anchor" id="dtree"></a>

# %% [markdown]
# Train a Decision Tree classifier and evaluating its performance

# %%
dt = ClassificationTree(random_state=42)
dt.fit(X_train, y_train)
analyze_results(dt, X_train, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       974
#            1       1.00      0.00      0.00       101
#
#     accuracy                           0.91      1075
#    macro avg       0.95      0.50      0.48      1075
# weighted avg       0.91      0.91      0.86      1075
#
# AUC-PR: 0.91

# %% [markdown]
# The results are terrible for class 1 (depression). We will try oversampling data to balance it.

# %%
X_train_over, y_train_over = oversample_data(X_train, y_train, strategy='auto')
# Out:
# Before oversampling: [(0, 3887), (1, 410)]
# After oversampling: [(0, 3887), (1, 3887)]

# %% [markdown]
# Train a new Decision Tree classifier and evaluate its performance

# %%
dt2 = ClassificationTree(random_state=42)
dt2.fit(X_train_over, y_train_over)
analyze_results(dt2, X_train_over, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.96      0.64      0.77       974
#            1       0.17      0.72      0.28       101
#
#     accuracy                           0.65      1075
#    macro avg       0.56      0.68      0.52      1075
# weighted avg       0.88      0.65      0.72      1075
#
# AUC-PR: 0.65

# %% [markdown]
# Despite a slight improvement in performance, the results are not still optimal.
# To gain insights and explanations, we will utilize the InterpretML package to get global and local explanations.

# %%
# Explain the global model
dt_global = dt2.explain_global(name="Classification Tree")
show(dt_global)

# Explain the local model
dt_local = dt2.explain_local(X_test, y_test, name="Classification Tree")
show(dt_local)
# Out:
# <!-- http://127.0.0.1:7756/2388343283568/ -->
# <iframe src="http://127.0.0.1:7756/2388343283568/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7756/2388373959584/ -->
# <iframe src="http://127.0.0.1:7756/2388373959584/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Explainable Boosting Classifier<a class="anchor" id="ebm"></a>

# %% [markdown]
# Train an Explainable Boosting classifier and evaluate its performance

# %%
ebm = ExplainableBoostingClassifier(random_state=42)
ebm.fit(X_train_over, y_train_over)
analyze_results(ebm, X_train_over, X_test, y_test, title='EXPLAINABLE BOOSTING CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: EXPLAINABLE BOOSTING CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88       974
#            1       0.21      0.43      0.28       101
#
#     accuracy                           0.80      1075
#    macro avg       0.57      0.63      0.58      1075
# weighted avg       0.87      0.80      0.83      1075
#
# AUC-PR: 0.80

# %% [markdown]
# Obtain global and local explanations using the InterpretML package

# %%
# Explain the global model
ebm_global = ebm.explain_global(name="EBM")
show(ebm_global)

# Explain the local model
ebm_local = ebm.explain_local(X_test, y_test)
show(ebm_local)
# Out:
# <!-- http://127.0.0.1:7756/2388375084960/ -->
# <iframe src="http://127.0.0.1:7756/2388375084960/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7756/2388377669536/ -->
# <iframe src="http://127.0.0.1:7756/2388377669536/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Random Forest<a class="anchor" id="rf"></a>

# %% [markdown]
# Create a RandomForestClassifier with balanced class weights, train the model on the training data, and analyze the results.

# %%
rf_clf = RandomForestClassifier(random_state=42, class_weight='balanced')
rf_clf.fit(X_train, y_train)
analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       974
#            1       0.00      0.00      0.00       101
#
#     accuracy                           0.91      1075
#    macro avg       0.45      0.50      0.48      1075
# weighted avg       0.82      0.91      0.86      1075
#
# AUC-PR: 0.91

# %% [markdown]
# The performance for class 1 is unsatisfactory. We will attempt to improve it by searching for the best parameters using GridSearchCV.

# %%
best_params_rf = {'criterion': ['gini', 'entropy'],
                  'max_depth': [3,4,5,6], 
                  'min_samples_split': [25,30,35],
                  'class_weight': ['balanced', 'balanced_subsample'], 
                  'n_estimators': [100,200,300]}

grid = GridSearchCV(rf_clf, best_params_rf, cv=5, scoring='accuracy')
rf_grid = grid.fit(X_train, y_train)

# %%
rf_grid.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_split': 25,
#  'n_estimators': 300}

# %%
rf_grid = rf_grid.best_estimator_
analyze_results(rf_grid, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88       974
#            1       0.24      0.57      0.34       101
#
#     accuracy                           0.79      1075
#    macro avg       0.60      0.69      0.61      1075
# weighted avg       0.88      0.79      0.83      1075
#
# AUC-PR: 0.79

# %%
# rf_clf = RandomForestClassifier(n_estimators=300, class_weight='balanced_subsample',
#                                 max_depth=6, min_samples_split=25,random_state=42)
# rf_clf.fit(X_train, y_train)
# analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87       974
#            1       0.24      0.55      0.33       101
#
#     accuracy                           0.79      1075
#    macro avg       0.59      0.68      0.60      1075
# weighted avg       0.88      0.79      0.82      1075
#
# AUC-PR: 0.79

# %% [markdown]
# We increased the performance, even though is still not good. We will use SHAP and LIME to get some explanations locally and globally

# %% [markdown]
# ### SHAP<a class="anchor" id="shap"></a>

# %% [markdown]
# Obtain global explanations for the first 20 instances using SHAP

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=0, end_index=20)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='i59HUWJEIQZCNRHSEGERQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.4992195211831663, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "total_cholesterol", "BMI", "alcohol_lifetime", "binge_drinking_lifetime", "number_drinks_last_year", "age_started_smoking", "smoke_lifetime", "number_cigarettes_last_month", "hours_sleep", "trouble_sleeping_history", "minutes_sedentary_activity", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "physical_activity_level_active", "physical_activity_level_moderately_active", "physical_activity_level_sedentary", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "explanations": [{"outValue": 0.2531190112265693, "simIndex": 15.0, "features": {"0": {"effect": -0.017515622809958484, "value": 18.0}, "1": {"effect": -0.0037614672169653755, "value": 7.0}, "2": {"effect": -0.06395048384386567, "value": 11.0}, "3": {"effect": -0.008818137120163147, "value": 112.0}, "4": {"effect": -0.013914971769294448, "value": 18.8}, "5": {"effect": 8.10237221246644e-05, "value": 1.0}, "6": {"effect": -0.010789636059740837, "value": 0.0}, "7": {"effect": -0.0056198405492801995, "value": 8.0}, "8": {"effect": 0.0035885640471764765, "value": 16.0}, "9": {"effect": 0.009609552615931955, "value": 1.0}, "10": {"effect": 0.0017404847218906781, "value": 20.0}, "11": {"effect": -0.014487127766126859, "value": 7.0}, "12": {"effect": -0.048835147525770055, "value": 0.0}, "13": {"effect": -0.0047201121100049455, "value": 300.0}, "14": {"effect": 0.001469636306479404, "value": 0.0}, "15": {"effect": -0.003249435563745157, "value": 1.0}, "16": {"effect": -8.732117618989912e-05, "value": 0.0}, "17": {"effect": -0.0041991125520743485, "value": 0.0}, "18": {"effect": 0.007589632542183408, "value": 0.0}, "19": {"effect": 0.0007855890860499047, "value": 0.0}, "20": {"effect": -0.0019345402282016004, "value": 0.0}, "21": {"effect": 0.00037210201059849216, "value": 0.0}, "22": {"effect": -0.003819172710837173, "value": 1.0}, "23": {"effect": -0.02249739801696008, "value": 0.0}, "24": {"effect": -0.026920899864046253, "value": 1.0}, "25": {"effect": -0.002011427767928201, "value": 0.0}, "26": {"effect": -0.00011794725270728511, "value": 0.0}, "27": {"effect": 0.008565904703576432, "value": 0.0}, "28": {"effect": -0.00048670672536211694, "value": 0.0}, "29": {"effect": -0.00045096057863240087, "value": 0.0}, "30": {"effect": -0.001869505277716174, "value": 1.0}, "31": {"effect": -0.0006703528688194177, "value": 0.0}, "32": {"effect": -0.00665219080103255, "value": 1.0}, "33": {"effect": 0.0018697608236440757, "value": 0.0}, "34": {"effect": -0.010543771053314856, "value": 0.0}, "35": {"effect": 0.000997995193248653, "value": 0.0}, "36": {"effect": -0.0014310528066357555, "value": 0.0}, "37": {"effect": -0.0005802944516501255, "value": 0.0}, "38": {"effect": -0.002213566875999039, "value": 1.0}, "39": {"effect": -0.0011849530064269077, "value": 0.0}, "40": {"effect": 0.0005624006199482542, "value": 0.0}}}, {"outValue": 0.541621080242919, "simIndex": 2.0, "features": {"0": {"effect": -0.009683887439993747, "value": 43.0}, "1": {"effect": -0.009634678745367537, "value": 5.0}, "2": {"effect": 0.032100296256761536, "value": 5.0}, "3": {"effect": -0.002343131423141359, "value": 198.0}, "4": {"effect": 0.018738752225296428, "value": 37.3}, "5": {"effect": -5.8045904150031175e-05, "value": 1.0}, "6": {"effect": -0.0076768435896485705, "value": 0.0}, "7": {" ...
# None

# %% [markdown]
# Obtain  explanations for instance 2 (Not Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=2, end_index=3)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='i9MTIMWTR2CWB45G6PCAP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.4992195211831663, "outValue": 0.15501782436871103, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "total_cholesterol", "BMI", "alcohol_lifetime", "binge_drinking_lifetime", "number_drinks_last_year", "age_started_smoking", "smoke_lifetime", "number_cigarettes_last_month", "hours_sleep", "trouble_sleeping_history", "minutes_sedentary_activity", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "physical_activity_level_active", "physical_activity_level_moderately_active", "physical_activity_level_sedentary", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "features": {"0": {"effect": -0.011762038834127022, "value": 45.0}, "1": {"effect": -0.002862101259134762, "value": 4.0}, "2": {"effect": -0.07984188444590143, "value": 12.0}, "3": {"effect": -0.005900732426780057, "value": 186.0}, "4": {"effect": -0.020207672029189407, "value": 22.3}, "5": {"effect": -1.8770422359132963e-05, "value": 0.0}, "6": {"effect": -0.008391236657025462, "value": 0.0}, "7": {"effect": -0.0018281819428227289, "value": 0.0}, "8": {"effect": -0.01443601645568487, "value": 0.0}, "9": {"effect": -0.018144970523678673, "value": 0.0}, "10": {"effect": -0.012754964138425584, "value": 0.0}, "11": {"effect": -0.004437895546105241, "value": 6.0}, "12": {"effect": -0.06817575483690609, "value": 0.0}, "13": {"effect": -0.002591271921127453, "value": 360.0}, "14": {"effect": -0.0005083789113921363, "value": 1.0}, "15": {"effect": -0.00039333372581589984, "value": 0.0}, "16": {"effect": -4.253296550647623e-05, "value": 0.0}, "17": {"effect": -0.003850461271550904, "value": 0.0}, "18": {"effect": -0.06663218508420488, "value": 1.0}, "19": {"effect": -0.00021456220023454835, "value": 0.0}, "20": {"effect": -0.0028605971903656493, "value": 0.0}, "21": {"effect": 0.0004129003444405824, "value": 0.0}, "22": {"effect": -0.00016288687163660838, "value": 0.0}, "23": {"effect": 0.013392276974774997, "value": 1.0}, "24": {"effect": 0.015672823680048867, "value": 0.0}, "25": {"effect": -0.00501016585009225, "value": 0.0}, "26": {"effect": -0.0004116411325059143, "value": 0.0}, "27": {"effect": -0.016496408001522984, "value": 1.0}, "28": {"effect": -3.992668591155767e-05, "value": 0.0}, "29": {"effect": -0.0002475756418764749, "value": 0.0}, "30": {"effect": -0.0005067924346523866, "value": 0.0}, "31": {"effect": -0.001214404383490551, "value": 0.0}, "32": {"effect": -0.005781918970142575, "value": 1.0}, "33": {"effect": 0.003671047593813826, "value": 0.0}, "34": {"effect": -0.016733274007358374, "value": 0.0}, "35": {"effect": 0.0006427950494591402, "value": 0.0}, "36": {"effect": -0.0011018171039788066, "value": 0.0}, "37": {"effect": -0.0006923481975513875, "value": 0.0}, "38": {"effect": -0.0008905276092832334, "value": 0.0}, "39": {"effect": -0.00026616871334549135, "value": 0.0}, "40": {"effect": -0.0025821420653057378, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i9MTIMWTR2CWB45G6PCAP')
#   );
# </script>
# None

# %% [markdown]
# Obtain  explanations for instance 108 (Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=108, end_index=109)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 1
# <div id='iZZQTDECJDZ4JTNLW8ZRD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.4992195211831663, "outValue": 0.7829134507054387, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "total_cholesterol", "BMI", "alcohol_lifetime", "binge_drinking_lifetime", "number_drinks_last_year", "age_started_smoking", "smoke_lifetime", "number_cigarettes_last_month", "hours_sleep", "trouble_sleeping_history", "minutes_sedentary_activity", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "physical_activity_level_active", "physical_activity_level_moderately_active", "physical_activity_level_sedentary", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "features": {"0": {"effect": 0.011709230663289228, "value": 63.0}, "1": {"effect": 0.0012937638246915493, "value": 1.0}, "2": {"effect": 0.03884922306575498, "value": 2.0}, "3": {"effect": -0.007019362993084221, "value": 159.0}, "4": {"effect": 0.024019014043873778, "value": 46.4}, "5": {"effect": -0.00273290915238251, "value": 0.0}, "6": {"effect": -0.005433834142898082, "value": 0.0}, "7": {"effect": -0.0034438833212624416, "value": 0.0}, "8": {"effect": 0.010520066376286325, "value": 18.0}, "9": {"effect": 0.011121875677088734, "value": 1.0}, "10": {"effect": 0.014153658462148326, "value": 300.0}, "11": {"effect": 0.017350630835789763, "value": 5.0}, "12": {"effect": 0.09184603514929605, "value": 1.0}, "13": {"effect": -0.002616392160936514, "value": 660.0}, "14": {"effect": 0.000522151911906628, "value": 1.0}, "15": {"effect": 0.00038896060178514905, "value": 0.0}, "16": {"effect": -2.8540735845779933e-05, "value": 0.0}, "17": {"effect": -0.0011773701066951107, "value": 0.0}, "18": {"effect": 0.009358868314693947, "value": 0.0}, "19": {"effect": 0.00025595993581743347, "value": 0.0}, "20": {"effect": 0.015000959336332694, "value": 1.0}, "21": {"effect": 0.00074489500360818, "value": 0.0}, "22": {"effect": 0.0005634781773405718, "value": 0.0}, "23": {"effect": 0.014828346508360504, "value": 1.0}, "24": {"effect": 0.014816725599998928, "value": 0.0}, "25": {"effect": -0.0014260225216518596, "value": 0.0}, "26": {"effect": 6.018185864332239e-05, "value": 0.0}, "27": {"effect": 0.005347318700040419, "value": 0.0}, "28": {"effect": 0.0008067027358606651, "value": 0.0}, "29": {"effect": -0.004540441432124812, "value": 1.0}, "30": {"effect": 0.00012738481163284866, "value": 0.0}, "31": {"effect": -0.0009629926524189315, "value": 0.0}, "32": {"effect": 0.004740311956691352, "value": 0.0}, "33": {"effect": 0.003600436650973471, "value": 0.0}, "34": {"effect": 0.018849130356260634, "value": 1.0}, "35": {"effect": 0.001617229431898478, "value": 0.0}, "36": {"effect": -0.00024432657736950524, "value": 1.0}, "37": {"effect": -0.0006378913614707582, "value": 0.0}, "38": {"effect": 0.0002493243020551956, "value": 0.0}, "39": {"effect": -0.0003974852115295981, "value": 0.0}, "40": {"effect": 0.0016135175998233434, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZZQTDECJDZ4JTNLW8ZRD')
#   );
# </script>
# None

# %% [markdown]
# ### LIME<a class="anchor" id="lime"></a>

# %% [markdown]
# Obtain local explanations for first 109 instances

# %%
lime_explanation(rf_grid, X_test, y_test, start_index=0, end_index=109)
# Out:
# <!-- http://127.0.0.1:7756/2388317787136/ -->
# <iframe src="http://127.0.0.1:7756/2388317787136/" width=100% height=800 frameBorder="0"></iframe>
