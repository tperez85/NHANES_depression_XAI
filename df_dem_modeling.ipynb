# %% [markdown]
# # TFG - Comprendiendo la depresión a traves de XAI
# Tamara Pérez Pérez
#
#
#
# ## Table of contents<a class="anchor" id="index"></a>

# %% [markdown]
# [Modeling Data: Demographic Dataset](#modeling-data)
# * [Imports](#imports)
# * [Demographic Dataset](#dataset)
#    * [Decision Tree Classifier](#dtree)
#    * [Explainable Boosting Classifier](#ebm)
#    * [Random Forest](#rf)
#        * [SHAP](#shap)
#        * [LIME](#lime)

# %% [markdown]
# ## Modeling Data: Demographic Dataset<a class="anchor" id="modeling-data"></a>

# %% [markdown]
# ### Imports<a class="anchor" id="imports"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_recall_curve
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree
from interpret.glassbox import (LogisticRegression,
                                ClassificationTree,
                                ExplainableBoostingClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from interpret.blackbox import LimeTabular
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss, TomekLinks
from imblearn.combine import SMOTETomek
from interpret import show
import shap
# %matplotlib inline
# %run functions.ipynb

# %% [markdown]
# Read the CSV file into a DataFrame and select relevant features for analysis.
# Preprocess binary responses, perform one-hot encoding on object columns, and display the head of the resulting DataFrame.

# %%
df = pd.read_csv('../csv/df.csv',index_col=0)
features = ['gender',
            'age',
            'race',
            'education_level',
            'marital_status',
            'people_in_the_household',
            'annual_household_income',
            'citizenship_status',
            'depression_status']
df_dem = select_features(df, features)
df_dem = preprocess_binary_responses(df_dem)
df_dem = one_hot_encode_object_columns(df_dem)
df_dem.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5372 entries, 73557 to 83727
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   age                                  5372 non-null   int64
#  1   people_in_the_household              5372 non-null   int64
#  2   annual_household_income              5372 non-null   int64
#  3   depression_status                    5372 non-null   int64
#  4   citizenship_status_citizen           5372 non-null   uint8
#  5   citizenship_status_not_citizen       5372 non-null   uint8
#  6   citizenship_status_unknown           5372 non-null   uint8
#  7   education_level_9-11th_grade         5372 non-null   uint8
#  8   education_level_college_graduate     5372 non-null   uint8
#  9   education_level_high_school          5372 non-null   uint8
#  10  education_level_less_than_9th_grade  5372 non-null   uint8
#  11  education_level_some_college         5372 non-null   uint8
#  12  education_level_unknown              5372 non-null   uint8
#  13  gender_female                        5372 non-null   uint8
#  14  gender_male                          5372 non-null   uint8
#  15  marital_status_divorced              5372 non-null   uint8
#  16  marital_status_living_with_partner   5372 non-null   uint8
#  17  marital_status_married               5372 non-null   uint8
#  18  marital_status_never_married         5372 non-null   uint8
#  19  marital_status_separated             5372 non-null   uint8
#  20  marital_status_unknown               5372 non-null   uint8
#  21  marital_status_widowed               5372 non-null   uint8
#  22  race_asian                           5372 non-null   uint8
#  23  race_black                           5372 non-null   uint8
#  24  race_hispanic                        5372 non-null   uint8
#  25  race_mexican                         5372 non-null   uint8
#  26  race_other_race                      5372 non-null   uint8
#  27  race_white                           5372 non-null   uint8
# dtypes: int64(4), uint8(24)
# memory usage: 335.8 KB
#        age  people_in_the_household  annual_household_income  \
# SEQN
# 73557   69                        3                        4
# 73558   54                        4                        7
# 73559   72                        2                       10
# 73561   73                        2                       12
# 73562   56                        1                        9
#
#        depression_status  citizenship_status_citizen  \
# SEQN
# 73557                  0                           1
# 73558                  0                           1
# 73559                  0                           1
# 73561                  0                           1
# 73562                  1                           1
#
#        citizenship_status_not_citizen  citizenship_status_unknown  \
# SEQN
# 73557                               0                           0
# 73558                               0                           0
# 73559                               0                           0
# 73561                               0                           0
# 73562                               0                           0
#
#        education_level_9-11th_grade  education_level_college_graduate  \
# SEQN
# 73557                             0                                 0
# 73558                             0                                 0
# 73559                             0                                 0
# 73561                             0                                 1
# 73562                             0                                 0
#
#        education_level_high_school  ...  marital_status_never_married  \
# SEQN                                ...
# 73557                            1  ...                             0
# 73558                            1  ...                             0
# 73559                            0  ...                             0
# 73561                            0  ...                             0
# 73562                            0  ...                             0
#
#        marital_status_separated  marital_status_unknown  \
# SEQN
# 73557                         1                       0
# 73558                         0                       0
# 73559                         0                       0
# 73561                         0                       0
# 73562                         0                       0
#
#        marital_status_widowed  race_asian  race_black  race_hispanic  \
# SEQN
# 73557                       0           0           1              0
# 73558                       0           0           0              0
# 73559                       0           0           0              0
# 73561                       0           0           0              0
# 73562                       0           0           0              0
#
#        race_mexican  race_other_race  race_white
# SEQN
# 73557             0                0           0
# 73558             0                0           1
# 73559             0                0           1
# 73561             0                0           1
# 73562             1                0           0
#
# [5 rows x 28 columns]

# %% [markdown]
# Split the dataset into training and testing sets using an 80-20 split

# %%
X_train, X_test, y_train, y_test = split_data(df_dem, target_column='depression_status', test_size=0.2, random_state=42)

# %% [markdown]
# ### Decision Tree Classifier<a class="anchor" id="dtree"></a>

# %% [markdown]
# Train a Decision Tree classifier and evaluating its performance

# %%
dt = ClassificationTree(random_state=42)
dt.fit(X_train, y_train)
analyze_results(dt, X_train, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       974
#            1       1.00      0.00      0.00       101
#
#     accuracy                           0.91      1075
#    macro avg       0.95      0.50      0.48      1075
# weighted avg       0.91      0.91      0.86      1075
#
# AUC-PR: 0.91

# %% [markdown]
# The results for class 1 (depression) are unsatisfactory. We will attempt oversampling to balance the data.

# %%
X_train_over, y_train_over = oversample_data(X_train, y_train, strategy='auto')
# Out:
# Before oversampling: [(0, 3887), (1, 410)]
# After oversampling: [(0, 3887), (1, 3887)]

# %% [markdown]
# Train a new Decision Tree classifier and evaluate its performance

# %%
dt2 = ClassificationTree(random_state=42)
dt2.fit(X_train_over, y_train_over)
analyze_results(dt2, X_train_over, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.97      0.30      0.46       974
#            1       0.12      0.92      0.21       101
#
#     accuracy                           0.36      1075
#    macro avg       0.55      0.61      0.34      1075
# weighted avg       0.89      0.36      0.44      1075
#
# AUC-PR: 0.36

# %% [markdown]
# Despite a slight improvement in performance, the results are not still optimal.
# To gain insights and explanations, we will utilize the InterpretML package to get global and local explanations.

# %%
# Explain the global model
dt_global = dt2.explain_global(name="Classification Tree")
show(dt_global)

# Explain the local model
dt_local = dt2.explain_local(X_test, y_test, name="Classification Tree")
show(dt_local)
# Out:
# <!-- http://127.0.0.1:7986/2217914256928/ -->
# <iframe src="http://127.0.0.1:7986/2217914256928/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7986/2217965009600/ -->
# <iframe src="http://127.0.0.1:7986/2217965009600/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Explainable Boosting Classifier<a class="anchor" id="ebm"></a>

# %% [markdown]
# Train an Explainable Boosting classifier and evaluate its performance

# %%
ebm = ExplainableBoostingClassifier(random_state=42)
ebm.fit(X_train_over, y_train_over)
analyze_results(ebm, X_train_over, X_test, y_test, title='EXPLAINABLE BOOSTING CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: EXPLAINABLE BOOSTING CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82       974
#            1       0.17      0.54      0.26       101
#
#     accuracy                           0.72      1075
#    macro avg       0.56      0.64      0.54      1075
# weighted avg       0.87      0.72      0.77      1075
#
# AUC-PR: 0.72

# %% [markdown]
# Obtain global and local explanations using the InterpretML package

# %%
# Explain the global model
ebm_global = ebm.explain_global(name="EBM")
show(ebm_global)

# Explain the local model
ebm_local = ebm.explain_local(X_test, y_test)
show(ebm_local)
# Out:
# <!-- http://127.0.0.1:7986/2217914800160/ -->
# <iframe src="http://127.0.0.1:7986/2217914800160/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7986/2217932067072/ -->
# <iframe src="http://127.0.0.1:7986/2217932067072/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Random Forest<a class="anchor" id="rf"></a>

# %% [markdown]
# Create a RandomForestClassifier with balanced class weights, train the model on the training data, and analyze the results.

# %%
rf_clf = RandomForestClassifier(random_state=42, class_weight='balanced')
rf_clf.fit(X_train, y_train)
analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       974
#            1       0.14      0.03      0.05       101
#
#     accuracy                           0.89      1075
#    macro avg       0.52      0.51      0.50      1075
# weighted avg       0.83      0.89      0.86      1075
#
# AUC-PR: 0.89

# %% [markdown]
# The performance for class 1 is unsatisfactory. We will attempt to improve it by searching for the best parameters using GridSearchCV.

# %%
best_params_rf = {'criterion': ['gini', 'entropy'],
                  'max_depth': [3,4,5,6], 
                  'min_samples_split': [25,30,35],
                  'class_weight': ['balanced', 'balanced_subsample'], 
                  'n_estimators': [100,200,300]}

grid = GridSearchCV(rf_clf, best_params_rf, cv=5, scoring='accuracy')
rf_grid = grid.fit(X_train, y_train)

# %%
rf_grid.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_split': 25,
#  'n_estimators': 300}

# %%
rf_grid = rf_grid.best_estimator_
analyze_results(rf_grid, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80       974
#            1       0.17      0.57      0.26       101
#
#     accuracy                           0.69      1075
#    macro avg       0.55      0.64      0.53      1075
# weighted avg       0.87      0.69      0.75      1075
#
# AUC-PR: 0.69

# %%
# rf_clf = RandomForestClassifier(n_estimators=300, class_weight='balanced_subsample',
#                                 max_depth=6, min_samples_split=25,random_state=42)
# rf_clf.fit(X_train, y_train)
# analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80       974
#            1       0.16      0.55      0.25       101
#
#     accuracy                           0.68      1075
#    macro avg       0.55      0.62      0.52      1075
# weighted avg       0.86      0.68      0.75      1075
#
# AUC-PR: 0.68

# %% [markdown]
# We increased the performance, even though is still not good. We will use SHAP and LIME to get some explanations locally and globally

# %% [markdown]
# ### SHAP<a class="anchor" id="shap"></a>

# %% [markdown]
# Obtain global explanations for the first 20 instances using SHAP

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=0, end_index=20)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='i58DRFV2LQLSKPMFPS0D9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49918035920487375, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "explanations": [{"outValue": 0.26454114959074976, "simIndex": 2.0, "features": {"0": {"effect": -0.0359389276041405, "value": 18.0}, "1": {"effect": -0.012178331997718124, "value": 7.0}, "2": {"effect": -0.1057195263020967, "value": 11.0}, "3": {"effect": -0.0029585744479573074, "value": 0.0}, "4": {"effect": -0.002217573447206315, "value": 1.0}, "5": {"effect": -0.0001591934654448783, "value": 0.0}, "6": {"effect": -0.008030187581828534, "value": 0.0}, "7": {"effect": 0.01141258450033287, "value": 0.0}, "8": {"effect": 0.00046642593114623864, "value": 0.0}, "9": {"effect": -0.005373895072565203, "value": 0.0}, "10": {"effect": 0.0012670411967094872, "value": 0.0}, "11": {"effect": 0.003080405914672254, "value": 1.0}, "12": {"effect": -0.031154659904034886, "value": 0.0}, "13": {"effect": -0.040141382561519674, "value": 1.0}, "14": {"effect": -0.0044529407497839735, "value": 0.0}, "15": {"effect": -0.00023824423119422997, "value": 0.0}, "16": {"effect": 0.013477453644224315, "value": 0.0}, "17": {"effect": 0.001801716676185898, "value": 0.0}, "18": {"effect": -0.000650797734706242, "value": 0.0}, "19": {"effect": -0.00318693954645629, "value": 1.0}, "20": {"effect": -0.004293839963049331, "value": 0.0}, "21": {"effect": 0.006216579916922394, "value": 0.0}, "22": {"effect": -0.0007005456824974012, "value": 0.0}, "23": {"effect": -0.0007257274047749216, "value": 0.0}, "24": {"effect": -0.01270318903995162, "value": 1.0}, "25": {"effect": -0.0012458954613307027, "value": 0.0}, "26": {"effect": -0.0002910451960606075, "value": 0.0}}}, {"outValue": 0.41987648110953624, "simIndex": 10.0, "features": {"0": {"effect": -0.016525757497079786, "value": 43.0}, "1": {"effect": -0.01919068327921257, "value": 5.0}, "2": {"effect": 0.03319023408486082, "value": 5.0}, "3": {"effect": 0.001037732162980735, "value": 1.0}, "4": {"effect": 0.0011263494464145286, "value": 0.0}, "5": {"effect": -0.00027919452251318194, "value": 0.0}, "6": {"effect": -0.007534648448903246, "value": 0.0}, "7": {"effect": 0.02386887938713827, "value": 0.0}, "8": {"effect": -0.000438787742897432, "value": 0.0}, "9": {"effect": -0.005976338182536541, "value": 0.0}, "10": {"effect": -0.001766573525124916, "value": 1.0}, "11": {"effect": 0.0011693040655332424, "value": 0.0}, "12": {"effect": -0.02922804322115815, "value": 0.0}, "13": {"effect": -0.04112260560438168, "value": 1.0}, "14": {"effect": -0.00493853079198737, "value": 0.0}, "15": {"effect": -0.0003476683116972605, "value": 0.0}, "16": {"effect": -0.017468344584582084, "value": 1.0}, "17": {"effect": 0.00013798734700836898, "value": 0.0}, "18": {"effect": -0.0006715213868916146, "value": 0.0}, "19": {"effect": 0.00048214742108186495, "value": 0.0}, "20": {"effect": -0.0015531704432119363, "value": 0.0}, "21": {"effect": 0.00870182624741401, "value": 0.0}, "22": {"effect": 2.2493359042111983e-05, "value": 0.0}, "23": {"effect": -0.0009746204943782035, "value": 0.0}, "24": {"effect": 0.002483951959319001, "value": 0.0}, "25": {"effect": -0.0034847455735417345, "value": 0.0}, "26": {"effect": -2.3549966032748926e-05, "value": 1.0}}}, {"outValue": 0.21025541505772205, "simIndex": 1.0, "feature ...
# None

# %% [markdown]
# Obtain  explanations for instance 2 (Not Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=2, end_index=3)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='iD18Q6M4UBAEDVJY8D9VL'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49918035920487375, "outValue": 0.21025541505772205, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "features": {"0": {"effect": -0.012732687530546738, "value": 45.0}, "1": {"effect": -0.009944492928389973, "value": 4.0}, "2": {"effect": -0.13290486333099188, "value": 12.0}, "3": {"effect": 0.0006492565153933331, "value": 1.0}, "4": {"effect": 6.481495187163835e-05, "value": 0.0}, "5": {"effect": -5.939156330625783e-05, "value": 0.0}, "6": {"effect": -0.010838495397943177, "value": 0.0}, "7": {"effect": -0.10986565002869947, "value": 1.0}, "8": {"effect": -0.0018525182044340158, "value": 0.0}, "9": {"effect": -0.0054788441514514495, "value": 0.0}, "10": {"effect": -0.0012931671860632603, "value": 0.0}, "11": {"effect": -0.0004213134664244491, "value": 0.0}, "12": {"effect": 0.019667072683798154, "value": 1.0}, "13": {"effect": 0.025197928173931888, "value": 0.0}, "14": {"effect": -0.006550863761382143, "value": 0.0}, "15": {"effect": -0.0016276218861597243, "value": 0.0}, "16": {"effect": -0.027485377434531, "value": 1.0}, "17": {"effect": 0.002329693594129203, "value": 0.0}, "18": {"effect": -0.0007605898954360612, "value": 0.0}, "19": {"effect": -0.00016077502478326416, "value": 0.0}, "20": {"effect": -0.0034701424913903766, "value": 0.0}, "21": {"effect": 0.0012920631716992492, "value": 0.0}, "22": {"effect": -0.0006054813206572566, "value": 0.0}, "23": {"effect": -0.0006655695053181021, "value": 0.0}, "24": {"effect": -0.000868318672412555, "value": 0.0}, "25": {"effect": -0.002321270120293452, "value": 0.0}, "26": {"effect": -0.00821833933736059, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iD18Q6M4UBAEDVJY8D9VL')
#   );
# </script>
# None

# %% [markdown]
# Obtain  explanations for instance 108 (Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=108, end_index=109)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 1
# <div id='iSVZ9FR6S27E5DL8ZABF9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49918035920487375, "outValue": 0.7482181433736894, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "features": {"0": {"effect": 0.03496167001633802, "value": 63.0}, "1": {"effect": -0.007180291346430987, "value": 1.0}, "2": {"effect": 0.06907927640327137, "value": 2.0}, "3": {"effect": 0.0034503071161856957, "value": 1.0}, "4": {"effect": 0.0024500683167554232, "value": 0.0}, "5": {"effect": -5.357642346646579e-05, "value": 0.0}, "6": {"effect": -0.004033856778870189, "value": 0.0}, "7": {"effect": 0.02034578231178849, "value": 0.0}, "8": {"effect": -0.0006855030428054442, "value": 0.0}, "9": {"effect": 0.0524174359214969, "value": 1.0}, "10": {"effect": 0.003673427052645434, "value": 0.0}, "11": {"effect": 0.002350176120403194, "value": 0.0}, "12": {"effect": 0.019075357211300773, "value": 1.0}, "13": {"effect": 0.03094196190264854, "value": 0.0}, "14": {"effect": -0.004104391877307499, "value": 0.0}, "15": {"effect": 0.0004203205891418561, "value": 0.0}, "16": {"effect": 0.00991957265139565, "value": 0.0}, "17": {"effect": 0.0014013148770862106, "value": 0.0}, "18": {"effect": 0.007791292753370701, "value": 1.0}, "19": {"effect": 0.0015514996405314042, "value": 0.0}, "20": {"effect": -0.0026532223482442574, "value": 0.0}, "21": {"effect": 0.00816127713843656, "value": 0.0}, "22": {"effect": -0.001374639567153507, "value": 1.0}, "23": {"effect": -0.0010324077044319285, "value": 0.0}, "24": {"effect": 0.004569602345360175, "value": 0.0}, "25": {"effect": -0.001808196208441514, "value": 0.0}, "26": {"effect": -0.0005964729021889995, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iSVZ9FR6S27E5DL8ZABF9')
#   );
# </script>
# None

# %% [markdown]
# ### LIME<a class="anchor" id="lime"></a>

# %% [markdown]
# Obtain local explanations for first 109 instances

# %%
lime_explanation(rf_grid, X_test, y_test, start_index=0, end_index=109)
# Out:
# <!-- http://127.0.0.1:7986/2217996115680/ -->
# <iframe src="http://127.0.0.1:7986/2217996115680/" width=100% height=800 frameBorder="0"></iframe>
