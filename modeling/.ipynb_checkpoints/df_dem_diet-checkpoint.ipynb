# %% [markdown]
# # TFG - Comprendiendo la depresión a traves de XAI
# Tamara Pérez Pérez
#
#
#
# ## Table of contents<a class="anchor" id="index"></a>

# %% [markdown]
# [Modeling Data: Demographic and Diet Dataset](#modeling-data)
# * [Imports](#imports)
# * [Demographic Dataset](#dataset)
#    * [Decision Tree Classifier](#dtree)
#    * [Explainable Boosting Classifier](#ebm)
#    * [Random Forest](#rf)
#        * [SHAP](#shap)
#        * [LIME](#lime)

# %% [markdown]
# ## Modeling Data: Demographic Dataset<a class="anchor" id="modeling-data"></a>

# %% [markdown]
# ### Imports<a class="anchor" id="imports"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_recall_curve
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree
from interpret.glassbox import (LogisticRegression,
                                ClassificationTree,
                                ExplainableBoostingClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from interpret.blackbox import LimeTabular
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss, TomekLinks
from imblearn.combine import SMOTETomek
from interpret import show
import shap
# %matplotlib inline
# %run functions.ipynb

# %% [markdown]
# ### Demographic Dataset<a class="anchor" id="dataset"></a>

# %%
df = pd.read_csv('../csv/df.csv',index_col=0)
features = ['gender',
            'age',
            'race',
            'education_level',
            'marital_status',
            'people_in_the_household',
            'annual_household_income',
            'citizenship_status',
            'macro_score',
            'mineral_score',
            'vitamin_score',
            'total_nutrient_score',
            'depression_status']
df_dem_diet = select_features(df, features)
df_dem_diet = preprocess_binary_responses(df_dem_diet)
df_dem_diet = one_hot_encode_object_columns(df_dem_diet)
df_dem_diet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5372 entries, 73557 to 83727
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   age                                  5372 non-null   int64
#  1   people_in_the_household              5372 non-null   int64
#  2   annual_household_income              5372 non-null   int64
#  3   macro_score                          5372 non-null   int64
#  4   mineral_score                        5372 non-null   int64
#  5   vitamin_score                        5372 non-null   int64
#  6   total_nutrient_score                 5372 non-null   int64
#  7   depression_status                    5372 non-null   int64
#  8   citizenship_status_citizen           5372 non-null   uint8
#  9   citizenship_status_not_citizen       5372 non-null   uint8
#  10  citizenship_status_unknown           5372 non-null   uint8
#  11  education_level_9-11th_grade         5372 non-null   uint8
#  12  education_level_college_graduate     5372 non-null   uint8
#  13  education_level_high_school          5372 non-null   uint8
#  14  education_level_less_than_9th_grade  5372 non-null   uint8
#  15  education_level_some_college         5372 non-null   uint8
#  16  education_level_unknown              5372 non-null   uint8
#  17  gender_female                        5372 non-null   uint8
#  18  gender_male                          5372 non-null   uint8
#  19  marital_status_divorced              5372 non-null   uint8
#  20  marital_status_living_with_partner   5372 non-null   uint8
#  21  marital_status_married               5372 non-null   uint8
#  22  marital_status_never_married         5372 non-null   uint8
#  23  marital_status_separated             5372 non-null   uint8
#  24  marital_status_unknown               5372 non-null   uint8
#  25  marital_status_widowed               5372 non-null   uint8
#  26  race_asian                           5372 non-null   uint8
#  27  race_black                           5372 non-null   uint8
#  28  race_hispanic                        5372 non-null   uint8
#  29  race_mexican                         5372 non-null   uint8
#  30  race_other_race                      5372 non-null   uint8
#  31  race_white                           5372 non-null   uint8
# dtypes: int64(8), uint8(24)
# memory usage: 503.6 KB
#        age  people_in_the_household  annual_household_income  macro_score  \
# SEQN
# 73557   69                        3                        4            3
# 73558   54                        4                        7            3
# 73559   72                        2                       10            3
# 73561   73                        2                       12            3
# 73562   56                        1                        9            1
#
#        mineral_score  vitamin_score  total_nutrient_score  depression_status  \
# SEQN
# 73557              3              2                     8                  0
# 73558              1              1                     5                  0
# 73559              0              3                     6                  0
# 73561              0              2                     5                  0
# 73562              0              5                     6                  1
#
#        citizenship_status_citizen  citizenship_status_not_citizen  ...  \
# SEQN                                                               ...
# 73557                           1                               0  ...
# 73558                           1                               0  ...
# 73559                           1                               0  ...
# 73561                           1                               0  ...
# 73562                           1                               0  ...
#
#        marital_status_never_married  marital_status_separated  \
# SEQN
# 73557                             0                         1
# 73558                             0                         0
# 73559                             0                         0
# 73561                             0                         0
# 73562                             0                         0
#
#        marital_status_unknown  marital_status_widowed  race_asian  race_black  \
# SEQN
# 73557                       0                       0           0           1
# 73558                       0                       0           0           0
# 73559                       0                       0           0           0
# 73561                       0                       0           0           0
# 73562                       0                       0           0           0
#
#        race_hispanic  race_mexican  race_other_race  race_white
# SEQN
# 73557              0             0                0           0
# 73558              0             0                0           1
# 73559              0             0                0           1
# 73561              0             0                0           1
# 73562              0             1                0           0
#
# [5 rows x 32 columns]

# %% [markdown]
# Splitting Train and Set

# %%
X_train, X_test, y_train, y_test = split_data(df_dem_diet, target_column='depression_status', test_size=0.2, random_state=42)

# %% [markdown]
# ### Decision Tree Classifier<a class="anchor" id="dtree"></a>

# %% [markdown]
# Training a Decision Tree classifier and evaluating its performance

# %%
dt = ClassificationTree(random_state=42)
dt.fit(X_train, y_train)
analyze_results(dt, X_train, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       974
#            1       0.00      0.00      0.00       101
#
#     accuracy                           0.91      1075
#    macro avg       0.45      0.50      0.48      1075
# weighted avg       0.82      0.91      0.86      1075
#
# AUC-PR: 0.91

# %% [markdown]
# The results are terrible for class 1 (depression). We will try oversampling data to balance it.

# %%
X_train_over, y_train_over = oversample_data(X_train, y_train, strategy='auto')
# Out:
# Before oversampling: [(0, 3887), (1, 410)]
# After oversampling: [(0, 3887), (1, 3887)]

# %%
dt2 = ClassificationTree(random_state=42)
dt2.fit(X_train_over, y_train_over)
analyze_results(dt2, X_train_over, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.97      0.30      0.46       974
#            1       0.12      0.92      0.21       101
#
#     accuracy                           0.36      1075
#    macro avg       0.55      0.61      0.34      1075
# weighted avg       0.89      0.36      0.44      1075
#
# AUC-PR: 0.36

# %%
# Explain the local model
dt_local = dt2.explain_local(X_test, y_test, name="Classification Tree")
show(dt_local)

# Explain the global model
dt_global = dt2.explain_global(name="Classification Tree")
show(dt_global)
# Out:
# <!-- http://127.0.0.1:7068/2950670485392/ -->
# <iframe src="http://127.0.0.1:7068/2950670485392/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7068/2950781357504/ -->
# <iframe src="http://127.0.0.1:7068/2950781357504/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Explainable Boosting Classifier<a class="anchor" id="ebm"></a>

# %% [markdown]
# Training an Explainable Boosting classifier and evaluating its performance

# %%
ebm = ExplainableBoostingClassifier(random_state=42)
ebm.fit(X_train_over, y_train_over)
analyze_results(ebm, X_train_over, X_test, y_test, title='EXPLAINABLE BOOSTING CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: EXPLAINABLE BOOSTING CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83      1459
#            1       0.17      0.52      0.26       153
#
#     accuracy                           0.72      1612
#    macro avg       0.56      0.63      0.54      1612
# weighted avg       0.86      0.72      0.77      1612
#
# AUC-PR: 0.72

# %% [markdown]
# Getting local and global explanations

# %%
# Explain the local model
ebm_local = ebm.explain_local(X_test, y_test)
show(ebm_local)

# Explain the global model
ebm_global = ebm.explain_global(name="EBM")
show(ebm_global)
# Out:
# <!-- http://127.0.0.1:7068/2952772541984/ -->
# <iframe src="http://127.0.0.1:7068/2952772541984/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7068/2950712928240/ -->
# <iframe src="http://127.0.0.1:7068/2950712928240/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Random Forest<a class="anchor" id="rf"></a>

# %%
# rf_clf = RandomForestClassifier(random_state=42, class_weight='balanced')
# rf_fit = rf_clf.fit(X_train, y_train)
# analyze_results(rf_fit, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      1459
#            1       0.75      0.02      0.04       153
#
#     accuracy                           0.91      1612
#    macro avg       0.83      0.51      0.49      1612
# weighted avg       0.89      0.91      0.86      1612
#
# AUC-PR: 0.91

# %% [markdown]
# The results are terrible for class 1. We will try to find best parameters using GridSearchCV

# %%
# best_params_rf = {'criterion': ['gini', 'entropy'],
#                   'max_depth': [3,4,5,6], 
#                   'min_samples_split': [25,30,35],
#                   'class_weight': ['balanced', 'balanced_subsample'], 
#                   'n_estimators': [100,200,300]}

# grid = GridSearchCV(rf_clf, best_params_rf, cv=5, scoring='accuracy')
# rf_grid = grid.fit(X_train, y_train)

# %%
# rf_grid.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': 6,
#  'min_samples_split': 25,
#  'n_estimators': 100}

# %%
rf_clf = RandomForestClassifier(n_estimators=100, class_weight='balanced_subsample',
                                max_depth=6, min_samples_split=25,random_state=42)
rf_clf.fit(X_train, y_train)
analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82       974
#            1       0.17      0.52      0.26       101
#
#     accuracy                           0.71      1075
#    macro avg       0.55      0.63      0.54      1075
# weighted avg       0.87      0.71      0.77      1075
#
# AUC-PR: 0.71

# %% [markdown]
# We increased the performance, even though is still not good. We will use SHAP and LIME to get some explanations locally and globally

# %% [markdown]
# ### SHAP<a class="anchor" id="shap"></a>

# %%
shap.initjs()
shap_explanation(rf_clf, X_test, start_index=1, end_index=None)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# (1074, 31)
# [array([[ 0.01442521,  0.01242221, -0.03017663, ..., -0.00153701,
#          0.00213318, -0.00091196],
#        [ 0.01504   ,  0.00308593,  0.09783268, ...,  0.00086045,
#          0.00129403,  0.00372552],
#        [ 0.04829935,  0.00430186,  0.12094397, ...,  0.00050976,
#          0.00171832,  0.00103733],
#        ...,
#        [ 0.02076847,  0.0073151 , -0.01400119, ..., -0.00293313,
#          0.00098755,  0.00298984],
#        [-0.03462407,  0.02195659, -0.02953004, ...,  0.00484709,
#          0.00191269,  0.00182456],
#        [ 0.02105731,  0.01547689, -0.02057078, ..., -0.00165736,
#          0.00184308, -0.00087293]]), array([[-0.01442521, -0.01242221,  0.03017663, ...,  0.00153701,
#         -0.00213318,  0.00091196],
#        [-0.01504   , -0.00308593, -0.09783268, ..., -0.00086045,
#         -0.00129403, -0.00372552],
#        [-0.04829935, -0.00430186, -0.12094397, ..., -0.00050976,
#         -0.00171832, -0.00103733],
#        ...,
#        [-0.02076847, -0.0073151 ,  0.01400119, ...,  0.00293313,
#         -0.00098755, -0.00298984],
#        [ 0.03462407, -0.02195659,  0.02953004, ..., -0.00484709,
#         -0.00191269, -0.00182456],
#        [-0.02105731, -0.01547689,  0.02057078, ...,  0.00165736,
#         -0.00184308,  0.00087293]])]
# Prediction: 0
# <div id='iMBUHL84JO285P7YBDNE0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5000000000000003, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "explanations": [{"outValue": 0.4062142980742333, "simIndex": 579.0, "features": {"0": {"effect": -0.014425213470497428, "value": 43.0}, "1": {"effect": -0.012422207053375585, "value": 5.0}, "2": {"effect": 0.030176632598334245, "value": 5.0}, "3": {"effect": -0.008520468335892607, "value": 3.0}, "4": {"effect": 0.0003240064943010266, "value": 2.0}, "5": {"effect": 0.0037110525405672475, "value": 0.0}, "6": {"effect": -0.01761938677494209, "value": 5.0}, "7": {"effect": 0.001302545554981195, "value": 1.0}, "8": {"effect": 0.0009677536653705773,