# %% [markdown]
# # TFG - Comprendiendo la depresión a traves de XAI
# Tamara Pérez Pérez
#
#
#
# ## Table of contents<a class="anchor" id="index"></a>

# %% [markdown]
# [Modeling Data: Diet Dataset](#modeling-data)
# * [Imports](#imports)
# * [Demographic Dataset](#dataset)
#    * [Decision Tree Classifier](#dtree)
#    * [Explainable Boosting Classifier](#ebm)
#    * [Random Forest](#rf)
#        * [SHAP](#shap)
#        * [LIME](#lime)

# %% [markdown]
# ## Modeling Data: Questionnaire and Diet Dataset<a class="anchor" id="modeling-data"></a>

# %% [markdown]
# ### Imports<a class="anchor" id="imports"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_recall_curve
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree
from interpret.glassbox import (LogisticRegression,
                                ClassificationTree,
                                ExplainableBoostingClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from interpret.blackbox import LimeTabular
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss, TomekLinks
from imblearn.combine import SMOTETomek
from interpret import show
import shap
# %matplotlib inline
# %run functions.ipynb

# %% [markdown]
# Read the CSV file into a DataFrame and select relevant features for analysis.
# Preprocess binary responses, perform one-hot encoding on object columns, and display the head of the resulting DataFrame.

# %%
df = pd.read_csv('../csv/df.csv',index_col=0)
features = ['macro_score',
            'mineral_score',
            'vitamin_score',
            'total_nutrient_score',
            'alcohol_lifetime',
            'binge_drinking_lifetime',
            'number_drinks_last_year',
            'age_started_smoking',
            'smoke_lifetime',
            'number_cigarettes_last_month',
            'hours_sleep',
            'trouble_sleeping_history',
            'minutes_sedentary_activity',
            'physical_activity_level',
            'depression_status']
df_quest_diet = select_features(df, features)
df_quest_diet = preprocess_binary_responses(df_quest_diet)
df_quest_diet = one_hot_encode_object_columns(df_quest_diet)
df_quest_diet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5372 entries, 73557 to 83727
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   macro_score                                5372 non-null   int64
#  1   mineral_score                              5372 non-null   int64
#  2   vitamin_score                              5372 non-null   int64
#  3   total_nutrient_score                       5372 non-null   int64
#  4   alcohol_lifetime                           5372 non-null   int64
#  5   binge_drinking_lifetime                    5372 non-null   int64
#  6   number_drinks_last_year                    5372 non-null   int64
#  7   age_started_smoking                        5372 non-null   int64
#  8   smoke_lifetime                             5372 non-null   int64
#  9   number_cigarettes_last_month               5372 non-null   float64
#  10  hours_sleep                                5372 non-null   int64
#  11  trouble_sleeping_history                   5372 non-null   int64
#  12  minutes_sedentary_activity                 5372 non-null   int64
#  13  depression_status                          5372 non-null   int64
#  14  physical_activity_level_active             5372 non-null   uint8
#  15  physical_activity_level_moderately_active  5372 non-null   uint8
#  16  physical_activity_level_sedentary          5372 non-null   uint8
# dtypes: float64(1), int64(13), uint8(3)
# memory usage: 645.3 KB
#        macro_score  mineral_score  vitamin_score  total_nutrient_score  \
# SEQN
# 73557            3              3              2                     8
# 73558            3              1              1                     5
# 73559            3              0              3                     6
# 73561            3              0              2                     5
# 73562            1              0              5                     6
#
#        alcohol_lifetime  binge_drinking_lifetime  number_drinks_last_year  \
# SEQN
# 73557                 1                        1                        3
# 73558                 1                        1                        7
# 73559                 1                        0                        0
# 73561                 1                        0                        0
# 73562                 1                        0                       15
#
#        age_started_smoking  smoke_lifetime  number_cigarettes_last_month  \
# SEQN
# 73557                   17               1                           0.0
# 73558                    0               1                           1.0
# 73559                   20               1                           0.0
# 73561                    0               0                           0.0
# 73562                   18               1                           0.0
#
#        hours_sleep  trouble_sleeping_history  minutes_sedentary_activity  \
# SEQN
# 73557            7                         1                         600
# 73558            9                         0                         540
# 73559            8                         0                         300
# 73561            9                         0                         480
# 73562            5                         0                         360
#
#        depression_status  physical_activity_level_active  \
# SEQN
# 73557                  0                               0
# 73558                  0                               0
# 73559                  0                               0
# 73561                  0                               0
# 73562                  1                               1
#
#        physical_activity_level_moderately_active  \
# SEQN
# 73557                                          0
# 73558                                          1
# 73559                                          1
# 73561                                          1
# 73562                                          0
#
#        physical_activity_level_sedentary
# SEQN
# 73557                                  1
# 73558                                  0
# 73559                                  0
# 73561                                  0
# 73562                                  0

# %% [markdown]
# Split the dataset into training and testing sets using an 80-20 split

# %%
X_train, X_test, y_train, y_test = split_data(df_quest_diet, target_column='depression_status', test_size=0.2, random_state=42)

# %% [markdown]
# ### Decision Tree Classifier<a class="anchor" id="dtree"></a>

# %% [markdown]
# Train a Decision Tree classifier and evaluate its performance

# %%
dt = ClassificationTree(random_state=42)
dt.fit(X_train, y_train)
analyze_results(dt, X_train, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       974
#            1       0.17      0.01      0.02       101
#
#     accuracy                           0.90      1075
#    macro avg       0.54      0.50      0.48      1075
# weighted avg       0.84      0.90      0.86      1075
#
# AUC-PR: 0.90

# %% [markdown]
# The results for class 1 (depression) are unsatisfactory. We will attempt oversampling to balance the data.

# %%
X_train_over, y_train_over = oversample_data(X_train, y_train, strategy='auto')
# Out:
# Before oversampling: [(0, 3887), (1, 410)]
# After oversampling: [(0, 3887), (1, 3887)]

# %% [markdown]
# Train a new Decision Tree classifier and evaluate its performance

# %%
dt2 = ClassificationTree(random_state=42)
dt2.fit(X_train_over, y_train_over)
analyze_results(dt2, X_train_over, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82       974
#            1       0.19      0.63      0.29       101
#
#     accuracy                           0.71      1075
#    macro avg       0.57      0.68      0.56      1075
# weighted avg       0.88      0.71      0.77      1075
#
# AUC-PR: 0.71

# %% [markdown]
# Despite a slight improvement in performance, the results are not still optimal.
# To gain insights and explanations, we will utilize the InterpretML package to get global and local explanations.

# %%
# Explain the global model
dt_global = dt2.explain_global(name="Classification Tree")
show(dt_global)

# Explain the local model
dt_local = dt2.explain_local(X_test, y_test, name="Classification Tree")
show(dt_local)
# Out:
# <!-- http://127.0.0.1:7404/3195291839456/ -->
# <iframe src="http://127.0.0.1:7404/3195291839456/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7404/3195292647328/ -->
# <iframe src="http://127.0.0.1:7404/3195292647328/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Explainable Boosting Classifier<a class="anchor" id="ebm"></a>

# %% [markdown]
# Train an Explainable Boosting classifier and evaluate its performance

# %%
ebm = ExplainableBoostingClassifier(random_state=42)
ebm.fit(X_train_over, y_train_over)
analyze_results(ebm, X_train_over, X_test, y_test, title='EXPLAINABLE BOOSTING CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: EXPLAINABLE BOOSTING CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86       974
#            1       0.20      0.47      0.28       101
#
#     accuracy                           0.77      1075
#    macro avg       0.57      0.63      0.57      1075
# weighted avg       0.87      0.77      0.81      1075
#
# AUC-PR: 0.77

# %% [markdown]
# Obtain global and local explanations using the InterpretML package

# %%
# Explain the global model
ebm_global = ebm.explain_global(name="EBM")
show(ebm_global)

# Explain the local model
ebm_local = ebm.explain_local(X_test, y_test)
show(ebm_local)
# Out:
# <!-- http://127.0.0.1:7404/3195291790976/ -->
# <iframe src="http://127.0.0.1:7404/3195291790976/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7404/3195291787712/ -->
# <iframe src="http://127.0.0.1:7404/3195291787712/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Random Forest<a class="anchor" id="rf"></a>

# %% [markdown]
# Create a RandomForestClassifier with balanced class weights, train the model on the training data, and analyze the results.

# %%
rf_clf = RandomForestClassifier(random_state=42, class_weight='balanced')
rf_clf.fit(X_train, y_train)
analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       974
#            1       0.17      0.01      0.02       101
#
#     accuracy                           0.90      1075
#    macro avg       0.54      0.50      0.48      1075
# weighted avg       0.84      0.90      0.86      1075
#
# AUC-PR: 0.90

# %% [markdown]
# The performance for class 1 is unsatisfactory. We will attempt to improve it by searching for the best parameters using GridSearchCV.

# %%
best_params_rf = {'criterion': ['gini', 'entropy'],
                  'max_depth': [3,4,5,6], 
                  'min_samples_split': [25,30,35],
                  'class_weight': ['balanced', 'balanced_subsample'], 
                  'n_estimators': [100,200,300]}

grid = GridSearchCV(rf_clf, best_params_rf, cv=5, scoring='accuracy')
rf_grid = grid.fit(X_train, y_train)

# %%
rf_grid.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_split': 25,
#  'n_estimators': 300}

# %%
rf_grid = rf_grid.best_estimator_
analyze_results(rf_grid, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87       974
#            1       0.23      0.54      0.32       101
#
#     accuracy                           0.79      1075
#    macro avg       0.59      0.68      0.60      1075
# weighted avg       0.88      0.79      0.82      1075
#
# AUC-PR: 0.79

# %%
# rf_clf = RandomForestClassifier(n_estimators=300, class_weight='balanced_subsample',
#                                 max_depth=6, min_samples_split=25,random_state=42)
# rf_clf.fit(X_train, y_train)
# analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87       974
#            1       0.23      0.55      0.33       101
#
#     accuracy                           0.79      1075
#    macro avg       0.59      0.68      0.60      1075
# weighted avg       0.88      0.79      0.82      1075
#
# AUC-PR: 0.79

# %% [markdown]
# We increased the performance, even though is still not good. We will use SHAP and LIME to get some explanations locally and globally

# %% [markdown]
# ### SHAP<a class="anchor" id="shap"></a>

# %% [markdown]
# Obtain global explanations for the first 20 instances using SHAP

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=0, end_index=20)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='iA2M0V0296M1W8H4RA3XN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49921952118316626, "link": "identity", "featureNames": ["macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "alcohol_lifetime", "binge_drinking_lifetime", "number_drinks_last_year", "age_started_smoking", "smoke_lifetime", "number_cigarettes_last_month", "hours_sleep", "trouble_sleeping_history", "minutes_sedentary_activity", "physical_activity_level_active", "physical_activity_level_moderately_active", "physical_activity_level_sedentary"], "explanations": [{"outValue": 0.2987367414460341, "simIndex": 14.0, "features": {"0": {"effect": -0.0036215002383927215, "value": 3.0}, "1": {"effect": -0.001482454167115099, "value": 1.0}, "2": {"effect": -0.000375307303290307, "value": 1.0}, "3": {"effect": -0.009444345236065105, "value": 5.0}, "4": {"effect": -0.0017697559082923192, "value": 1.0}, "5": {"effect": -0.017586490317228698, "value": 0.0}, "6": {"effect": -0.011877271855789993, "value": 8.0}, "7": {"effect": 0.012469496667789263, "value": 16.0}, "8": {"effect": 0.016913268439712546, "value": 1.0}, "9": {"effect": -0.004711870246594939, "value": 20.0}, "10": {"effect": -0.030147454063127292, "value": 7.0}, "11": {"effect": -0.10593243625121379, "value": 0.0}, "12": {"effect": -0.006058641845920932, "value": 300.0}, "13": {"effect": -0.011478263420707584, "value": 1.0}, "14": {"effect": 0.0025275623104562155, "value": 0.0}, "15": {"effect": -0.027907316301351372, "value": 0.0}}}, {"outValue": 0.4980114641159507, "simIndex": 3.0, "features": {"0": {"effect": -0.0039189214243869775, "value": 3.0}, "1": {"effect": -0.010414858823493597, "value": 2.0}, "2": {"effect": -0.0023505974565921506, "value": 0.0}, "3": {"effect": -0.008961181787480262, "value": 5.0}, "4": {"effect": -0.0031767536267958926, "value": 1.0}, "5": {"effect": -0.007896304839420715, "value": 0.0}, "6": {"effect": -0.01932467476666702, "value": 2.0}, "7": {"effect": 0.006201444586346295, "value": 13.0}, "8": {"effect": 0.013761946157822448, "value": 1.0}, "9": {"effect": -0.029930775011008867, "value": 0.0}, "10": {"effect": -0.028501050430265348, "value": 8.0}, "11": {"effect": 0.15007879834228774, "value": 1.0}, "12": {"effect": -0.0006518363823480295, "value": 300.0}, "13": {"effect": -0.017813934912560444, "value": 1.0}, "14": {"effect": 0.003993921153949963, "value": 0.0}, "15": {"effect": -0.04230327784660268, "value": 0.0}}}, {"outValue": 0.27163221912889274, "simIndex": 8.0, "features": {"0": {"effect": -0.0022486350201800336, "value": 4.0}, "1": {"effect": -0.0009573232437044865, "value": 2.0}, "2": {"effect": -0.005546693819738133, "value": 2.0}, "3": {"effect": -0.0159069165897938, "value": 8.0}, "4": {"effect": -0.0008371004195307808, "value": 0.0}, "5": {"effect": -0.0085994978370142, "value": 0.0}, "6": {"effect": -0.0016211361768753857, "value": 0.0}, "7": {"effect": -0.018709457614758226, "value": 0.0}, "8": {"effect": -0.013595512431169163, "value": 0.0}, "9": {"effect": -0.016028488267475622, "value": 0.0}, "10": {"effect": 0.0019289390533609567, "value": 6.0}, "11": {"effect": -0.10079809093564408, "value": 0.0}, "12": {"effect": -0.0011547319307775184, "value": 360.0}, "13": {"effect": -0.013181113532114546, "value": 1.0}, "14": {"effect": 0.0027329158295223656, "value": 0.0}, "15": {"effect": -0.03306445911838085, "value": 0.0}}}, {"outValue": 0.2188011189238251, "simIndex": 7.0, "features": {"0": {"effect": -0.004826347826109635, "value": 1.0}, "1": {"effect": -0.0041219070752609, "value": 0.0}, "2": {"effect": -0.014095752683231882, "value": 3.0}, "3": {"effect": -0.009389830192800853, "value": 4.0}, "4": {"effect": -0.00035564388262595236, "value": 1.0}, "5": {"effect": -0.00980448186673606, "value": 0.0}, "6": {"effect": -0.016752014212291846, "value": 1.0}, "7": {"effect": -0.02454850066303979, "value": 0.0}, "8": {"effect": -0.01673036137363915, "value": 0.0}, "9": {"effect": -0.01601562264001946, "value": 0.0}, "10": ...
# None

# %% [markdown]
# Obtain  explanations for instance 2 (Not Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=2, end_index=3)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='iP853OBJ02J2AWJF19YE8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49921952118316626, "outValue": 0.27163221912889274, "link": "identity", "featureNames": ["macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "alcohol_lifetime", "binge_drinking_lifetime", "number_drinks_last_year", "age_started_smoking", "smoke_lifetime", "number_cigarettes_last_month", "hours_sleep", "trouble_sleeping_history", "minutes_sedentary_activity", "physical_activity_level_active", "physical_activity_level_moderately_active", "physical_activity_level_sedentary"], "features": {"0": {"effect": -0.0022486350201800336, "value": 4.0}, "1": {"effect": -0.0009573232437044865, "value": 2.0}, "2": {"effect": -0.005546693819738133, "value": 2.0}, "3": {"effect": -0.0159069165897938, "value": 8.0}, "4": {"effect": -0.0008371004195307808, "value": 0.0}, "5": {"effect": -0.0085994978370142, "value": 0.0}, "6": {"effect": -0.0016211361768753857, "value": 0.0}, "7": {"effect": -0.018709457614758226, "value": 0.0}, "8": {"effect": -0.013595512431169163, "value": 0.0}, "9": {"effect": -0.016028488267475622, "value": 0.0}, "10": {"effect": 0.0019289390533609567, "value": 6.0}, "11": {"effect": -0.10079809093564408, "value": 0.0}, "12": {"effect": -0.0011547319307775184, "value": 360.0}, "13": {"effect": -0.013181113532114546, "value": 1.0}, "14": {"effect": 0.0027329158295223656, "value": 0.0}, "15": {"effect": -0.03306445911838085, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iP853OBJ02J2AWJF19YE8')
#   );
# </script>
# None

# %%
X_test[2:3]
# Out:
#        macro_score  mineral_score  vitamin_score  total_nutrient_score  \
# SEQN
# 81317            4              2              2                     8
#
#        alcohol_lifetime  binge_drinking_lifetime  number_drinks_last_year  \
# SEQN
# 81317                 0                        0                        0
#
#        age_started_smoking  smoke_lifetime  number_cigarettes_last_month  \
# SEQN
# 81317                    0               0                           0.0
#
#        hours_sleep  trouble_sleeping_history  minutes_sedentary_activity  \
# SEQN
# 81317            6                         0                         360
#
#        physical_activity_level_active  \
# SEQN
# 81317                               1
#
#        physical_activity_level_moderately_active  \
# SEQN
# 81317                                          0
#
#        physical_activity_level_sedentary
# SEQN
# 81317                                  0

# %% [markdown]
# Obtain  explanations for instance 108 (Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=108, end_index=109)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 1
# <div id='i3Z67E1DEIAQ38SKW3SRE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49921952118316626, "outValue": 0.8036020676218047, "link": "identity", "featureNames": ["macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "alcohol_lifetime", "binge_drinking_lifetime", "number_drinks_last_year", "age_started_smoking", "smoke_lifetime", "number_cigarettes_last_month", "hours_sleep", "trouble_sleeping_history", "minutes_sedentary_activity", "physical_activity_level_active", "physical_activity_level_moderately_active", "physical_activity_level_sedentary"], "features": {"0": {"effect": 0.010254189903251889, "value": 1.0}, "1": {"effect": -0.006203318426422969, "value": 1.0}, "2": {"effect": 0.010017606875785578, "value": 0.0}, "3": {"effect": 0.01898585364674653, "value": 2.0}, "4": {"effect": 0.00010878501888413084, "value": 0.0}, "5": {"effect": -0.009210614722041969, "value": 0.0}, "6": {"effect": -0.0022334114998480165, "value": 0.0}, "7": {"effect": 0.017375552341001486, "value": 18.0}, "8": {"effect": 0.00983285112069191, "value": 1.0}, "9": {"effect": 0.032793024255441894, "value": 300.0}, "10": {"effect": 0.03723067396707152, "value": 5.0}, "11": {"effect": 0.12930391993267873, "value": 1.0}, "12": {"effect": -0.004528761255997925, "value": 660.0}, "13": {"effect": 0.006925714431808195, "value": 0.0}, "14": {"effect": 0.006052457500072793, "value": 0.0}, "15": {"effect": 0.047678023349514695, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i3Z67E1DEIAQ38SKW3SRE')
#   );
# </script>
# None

# %% [markdown]
# ### LIME<a class="anchor" id="lime"></a>

# %% [markdown]
# Obtain local explanations for first 108 instances

# %%
lime_explanation(rf_grid, X_test, y_test, start_index=0, end_index=109)
# Out:
# <!-- http://127.0.0.1:7404/3195292107056/ -->
# <iframe src="http://127.0.0.1:7404/3195292107056/" width=100% height=800 frameBorder="0"></iframe>
