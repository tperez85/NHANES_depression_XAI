# %% [markdown]
# # TFG - Comprendiendo la depresión a traves de XAI
# Tamara Pérez Pérez
#
#
#
# ## Table of contents<a class="anchor" id="index"></a>

# %% [markdown]
# [Modeling Data: Demographic and Diet Dataset](#modeling-data)
# * [Imports](#imports)
# * [Demographic Dataset](#dataset)
#    * [Decision Tree Classifier](#dtree)
#    * [Explainable Boosting Classifier](#ebm)
#    * [Random Forest](#rf)
#        * [SHAP](#shap)
#        * [LIME](#lime)

# %% [markdown]
# ## Modeling Data: Demographic and Diet Dataset<a class="anchor" id="modeling-data"></a>

# %% [markdown]
# ### Imports<a class="anchor" id="imports"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score, precision_recall_curve
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree
from interpret.glassbox import (LogisticRegression,
                                ClassificationTree,
                                ExplainableBoostingClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from interpret.blackbox import LimeTabular
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import NearMiss, TomekLinks
from imblearn.combine import SMOTETomek
from interpret import show
import shap
# %matplotlib inline
# %run functions.ipynb

# %% [markdown]
# Read the CSV file into a DataFrame and select relevant features for analysis.
# Preprocess binary responses, perform one-hot encoding on object columns, and display the head of the resulting DataFrame.

# %%
df = pd.read_csv('../csv/df.csv',index_col=0)
features = ['gender',
            'age',
            'race',
            'education_level',
            'marital_status',
            'people_in_the_household',
            'annual_household_income',
            'citizenship_status',
            'macro_score',
            'mineral_score',
            'vitamin_score',
            'total_nutrient_score',
            'depression_status']
df_dem_diet = select_features(df, features)
df_dem_diet = preprocess_binary_responses(df_dem_diet)
df_dem_diet = one_hot_encode_object_columns(df_dem_diet)
df_dem_diet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5372 entries, 73557 to 83727
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   age                                  5372 non-null   int64
#  1   people_in_the_household              5372 non-null   int64
#  2   annual_household_income              5372 non-null   int64
#  3   macro_score                          5372 non-null   int64
#  4   mineral_score                        5372 non-null   int64
#  5   vitamin_score                        5372 non-null   int64
#  6   total_nutrient_score                 5372 non-null   int64
#  7   depression_status                    5372 non-null   int64
#  8   citizenship_status_citizen           5372 non-null   uint8
#  9   citizenship_status_not_citizen       5372 non-null   uint8
#  10  citizenship_status_unknown           5372 non-null   uint8
#  11  education_level_9-11th_grade         5372 non-null   uint8
#  12  education_level_college_graduate     5372 non-null   uint8
#  13  education_level_high_school          5372 non-null   uint8
#  14  education_level_less_than_9th_grade  5372 non-null   uint8
#  15  education_level_some_college         5372 non-null   uint8
#  16  education_level_unknown              5372 non-null   uint8
#  17  gender_female                        5372 non-null   uint8
#  18  gender_male                          5372 non-null   uint8
#  19  marital_status_divorced              5372 non-null   uint8
#  20  marital_status_living_with_partner   5372 non-null   uint8
#  21  marital_status_married               5372 non-null   uint8
#  22  marital_status_never_married         5372 non-null   uint8
#  23  marital_status_separated             5372 non-null   uint8
#  24  marital_status_unknown               5372 non-null   uint8
#  25  marital_status_widowed               5372 non-null   uint8
#  26  race_asian                           5372 non-null   uint8
#  27  race_black                           5372 non-null   uint8
#  28  race_hispanic                        5372 non-null   uint8
#  29  race_mexican                         5372 non-null   uint8
#  30  race_other_race                      5372 non-null   uint8
#  31  race_white                           5372 non-null   uint8
# dtypes: int64(8), uint8(24)
# memory usage: 503.6 KB
#        age  people_in_the_household  annual_household_income  macro_score  \
# SEQN
# 73557   69                        3                        4            3
# 73558   54                        4                        7            3
# 73559   72                        2                       10            3
# 73561   73                        2                       12            3
# 73562   56                        1                        9            1
#
#        mineral_score  vitamin_score  total_nutrient_score  depression_status  \
# SEQN
# 73557              3              2                     8                  0
# 73558              1              1                     5                  0
# 73559              0              3                     6                  0
# 73561              0              2                     5                  0
# 73562              0              5                     6                  1
#
#        citizenship_status_citizen  citizenship_status_not_citizen  ...  \
# SEQN                                                               ...
# 73557                           1                               0  ...
# 73558                           1                               0  ...
# 73559                           1                               0  ...
# 73561                           1                               0  ...
# 73562                           1                               0  ...
#
#        marital_status_never_married  marital_status_separated  \
# SEQN
# 73557                             0                         1
# 73558                             0                         0
# 73559                             0                         0
# 73561                             0                         0
# 73562                             0                         0
#
#        marital_status_unknown  marital_status_widowed  race_asian  race_black  \
# SEQN
# 73557                       0                       0           0           1
# 73558                       0                       0           0           0
# 73559                       0                       0           0           0
# 73561                       0                       0           0           0
# 73562                       0                       0           0           0
#
#        race_hispanic  race_mexican  race_other_race  race_white
# SEQN
# 73557              0             0                0           0
# 73558              0             0                0           1
# 73559              0             0                0           1
# 73561              0             0                0           1
# 73562              0             1                0           0
#
# [5 rows x 32 columns]

# %% [markdown]
# Split the dataset into training and testing sets using an 80-20 split

# %%
X_train, X_test, y_train, y_test = split_data(df_dem_diet, target_column='depression_status', test_size=0.2, random_state=42)

# %% [markdown]
# ### Decision Tree Classifier<a class="anchor" id="dtree"></a>

# %% [markdown]
# Train a Decision Tree classifier and evaluating its performance

# %%
dt = ClassificationTree(random_state=42)
dt.fit(X_train, y_train)
analyze_results(dt, X_train, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       974
#            1       0.00      0.00      0.00       101
#
#     accuracy                           0.91      1075
#    macro avg       0.45      0.50      0.48      1075
# weighted avg       0.82      0.91      0.86      1075
#
# AUC-PR: 0.91

# %% [markdown]
# The results for class 1 (depression) are unsatisfactory. We will attempt oversampling to balance the data.

# %%
X_train_over, y_train_over = oversample_data(X_train, y_train, strategy='auto')
# Out:
# Before oversampling: [(0, 3887), (1, 410)]
# After oversampling: [(0, 3887), (1, 3887)]

# %% [markdown]
# Train a new Decision Tree classifier and evaluate its performance

# %%
dt2 = ClassificationTree(random_state=42)
dt2.fit(X_train_over, y_train_over)
analyze_results(dt2, X_train_over, X_test, y_test, title='DECISION TREE CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: DECISION TREE CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.97      0.30      0.46       974
#            1       0.12      0.92      0.21       101
#
#     accuracy                           0.36      1075
#    macro avg       0.55      0.61      0.34      1075
# weighted avg       0.89      0.36      0.44      1075
#
# AUC-PR: 0.36

# %% [markdown]
# Despite a slight improvement in performance, the results are not still optimal.
# To gain insights and explanations, we will utilize the InterpretML package to get global and local explanations.

# %%
# Explain the global model
dt_global = dt2.explain_global(name="Classification Tree")
show(dt_global)

# Explain the local model
dt_local = dt2.explain_local(X_test, y_test, name="Classification Tree")
show(dt_local)
# Out:
# <!-- http://127.0.0.1:7254/2555185565360/ -->
# <iframe src="http://127.0.0.1:7254/2555185565360/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7254/2555189358752/ -->
# <iframe src="http://127.0.0.1:7254/2555189358752/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Explainable Boosting Classifier<a class="anchor" id="ebm"></a>

# %% [markdown]
# Train an Explainable Boosting classifier and evaluate its performance

# %%
ebm = ExplainableBoostingClassifier(random_state=42)
ebm.fit(X_train_over, y_train_over)
analyze_results(ebm, X_train_over, X_test, y_test, title='EXPLAINABLE BOOSTING CLASSIFIER')
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR: EXPLAINABLE BOOSTING CLASSIFIER
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83       974
#            1       0.16      0.46      0.23       101
#
#     accuracy                           0.72      1075
#    macro avg       0.54      0.60      0.53      1075
# weighted avg       0.86      0.72      0.77      1075
#
# AUC-PR: 0.72

# %% [markdown]
# Obtain global and local explanations using the InterpretML package

# %%
# Explain the global model
ebm_global = ebm.explain_global(name="EBM")
show(ebm_global)

# Explain the local model
ebm_local = ebm.explain_local(X_test, y_test)
show(ebm_local)
# Out:
# <!-- http://127.0.0.1:7254/2554939231536/ -->
# <iframe src="http://127.0.0.1:7254/2554939231536/" width=100% height=800 frameBorder="0"></iframe>
# <!-- http://127.0.0.1:7254/2555190129280/ -->
# <iframe src="http://127.0.0.1:7254/2555190129280/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Random Forest<a class="anchor" id="rf"></a>

# %% [markdown]
# Create a RandomForestClassifier with balanced class weights, train the model on the training data, and analyze the results.

# %%
rf_clf = RandomForestClassifier(random_state=42, class_weight='balanced')
rf_clf.fit(X_train, y_train)
analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       974
#            1       1.00      0.02      0.04       101
#
#     accuracy                           0.91      1075
#    macro avg       0.95      0.51      0.50      1075
# weighted avg       0.92      0.91      0.87      1075
#
# AUC-PR: 0.91

# %% [markdown]
# The results are terrible for class 1. We will try to find best parameters using GridSearchCV

# %%
best_params_rf = {'criterion': ['gini', 'entropy'],
                  'max_depth': [3,4,5,6], 
                  'min_samples_split': [25,30,35],
                  'class_weight': ['balanced', 'balanced_subsample'], 
                  'n_estimators': [100,200,300]}

grid = GridSearchCV(rf_clf, best_params_rf, cv=5, scoring='accuracy')
rf_grid = grid.fit(X_train, y_train)

# %%
rf_grid.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_split': 25,
#  'n_estimators': 100}

# %%
rf_grid = rf_grid.best_estimator_
analyze_results(rf_grid, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82       974
#            1       0.16      0.50      0.24       101
#
#     accuracy                           0.71      1075
#    macro avg       0.55      0.61      0.53      1075
# weighted avg       0.86      0.71      0.76      1075
#
# AUC-PR: 0.71

# %%
# rf_clf = RandomForestClassifier(n_estimators=100, class_weight='balanced_subsample',
#                                 max_depth=6, min_samples_split=25,random_state=42)
# rf_clf.fit(X_train, y_train)
# analyze_results(rf_clf, X_train, X_test, y_test)
# Out:
# ____________________________________________________________
#
# CLASSIFICATION REPORT FOR:
# ____________________________________________________________
#               precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82       974
#            1       0.17      0.52      0.26       101
#
#     accuracy                           0.71      1075
#    macro avg       0.55      0.63      0.54      1075
# weighted avg       0.87      0.71      0.77      1075
#
# AUC-PR: 0.71

# %% [markdown]
# We increased the performance, even though is still not good. We will use SHAP and LIME to get some explanations locally and globally

# %% [markdown]
# ### SHAP<a class="anchor" id="shap"></a>

# %% [markdown]
# Obtain global explanations for the first 20 instances using SHAP

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=0, end_index=20)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='iH9TVRM7J49PMG5CZ480E'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49918035920487397, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "explanations": [{"outValue": 0.3352619876350455, "simIndex": 5.0, "features": {"0": {"effect": -0.021871599343147457, "value": 18.0}, "1": {"effect": -0.00857514114057204, "value": 7.0}, "2": {"effect": -0.07700507695331095, "value": 11.0}, "3": {"effect": -0.010323806462222435, "value": 3.0}, "4": {"effect": 0.002650805483659083, "value": 1.0}, "5": {"effect": 0.005431868070748061, "value": 1.0}, "6": {"effect": -0.006102693072235426, "value": 5.0}, "7": {"effect": -0.0017624414049475041, "value": 0.0}, "8": {"effect": -0.001453223627272331, "value": 1.0}, "9": {"effect": -0.00017896108127963878, "value": 0.0}, "10": {"effect": -0.005440729057514285, "value": 0.0}, "11": {"effect": 0.014397759901018652, "value": 0.0}, "12": {"effect": 0.0006450079975823977, "value": 0.0}, "13": {"effect": -0.0036758113885124863, "value": 0.0}, "14": {"effect": 0.0003626296962278981, "value": 0.0}, "15": {"effect": -0.001962372729659737, "value": 1.0}, "16": {"effect": -0.03286066701088057, "value": 0.0}, "17": {"effect": -0.02737415246537178, "value": 1.0}, "18": {"effect": -0.004863127631883264, "value": 0.0}, "19": {"effect": 0.00012904863961635198, "value": 0.0}, "20": {"effect": 0.016428437370016293, "value": 0.0}, "21": {"effect": 0.0016188895641212893, "value": 0.0}, "22": {"effect": -0.0001802314946886991, "value": 0.0}, "23": {"effect": -0.0035535588749034328, "value": 1.0}, "24": {"effect": -0.0018989734151139378, "value": 0.0}, "25": {"effect": 0.004900876432994435, "value": 0.0}, "26": {"effect": 0.00017946620137935675, "value": 0.0}, "27": {"effect": -0.0017953310960918136, "value": 0.0}, "28": {"effect": 0.0034338073017910705, "value": 1.0}, "29": {"effect": -0.0012200790090463238, "value": 0.0}, "30": {"effect": -0.001998990970329223, "value": 0.0}}}, {"outValue": 0.384450424224404, "simIndex": 9.0, "features": {"0": {"effect": -0.013378696416745607, "value": 43.0}, "1": {"effect": -0.013539214779025385, "value": 5.0}, "2": {"effect": 0.028561860247891414, "value": 5.0}, "3": {"effect": -0.011042062358264519, "value": 3.0}, "4": {"effect": -0.002144788741230056, "value": 2.0}, "5": {"effect": -0.0013425639026623843, "value": 0.0}, "6": {"effect": -0.01921958512686319, "value": 5.0}, "7": {"effect": 0.0010487755627807355, "value": 1.0}, "8": {"effect": 0.0008885831670644066, "value": 0.0}, "9": {"effect": -0.0003319646125058888, "value": 0.0}, "10": {"effect": -0.007449012355624831, "value": 0.0}, "11": {"effect": 0.02247806307463455, "value": 0.0}, "12": {"effect": 0.0002463329921393561, "value": 0.0}, "13": {"effect": -0.005423194568793438, "value": 0.0}, "14": {"effect": -0.002419149019287029, "value": 1.0}, "15": {"effect": 0.000771725938565551, "value": 0.0}, "16": {"effect": -0.03734415948876522, "value": 0.0}, "17": {"effect": -0.03379485036530397, "value": 1.0}, "18": {"effect": -0.00447899526890574, "value": 0.0}, "19": {"effect": -0.00011874638058876682, "value": 0.0}, "20": {"effect": -0.018729636939565565, "value": 1.0}, "21": {"effect": 0.0009722780708679833, "value": 0.0}, "22": {"effect": -0.0007888081557424143, "value ...
# None

# %% [markdown]
# Obtain  explanations for instance 2 (Not Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=2, end_index=3)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 0
# <div id='iXK8LSDTP34GXIL3KQDOF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49918035920487397, "outValue": 0.2466002461258156, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "features": {"0": {"effect": -0.017350232165770682, "value": 45.0}, "1": {"effect": -0.00355136791903286, "value": 4.0}, "2": {"effect": -0.10403328376308592, "value": 12.0}, "3": {"effect": -0.0071615553956267146, "value": 4.0}, "4": {"effect": -0.0024360952560185598, "value": 2.0}, "5": {"effect": -0.007943536118830318, "value": 2.0}, "6": {"effect": -0.007105500996767056, "value": 8.0}, "7": {"effect": 0.00033090918042659765, "value": 1.0}, "8": {"effect": 0.00013784433249283362, "value": 0.0}, "9": {"effect": -4.022977793354819e-05, "value": 0.0}, "10": {"effect": -0.009788584371108626, "value": 0.0}, "11": {"effect": -0.09983931738754219, "value": 1.0}, "12": {"effect": -0.0005474844981602278, "value": 0.0}, "13": {"effect": -0.0030871748871568474, "value": 0.0}, "14": {"effect": 0.00017489195566978936, "value": 0.0}, "15": {"effect": 0.00019227366636118156, "value": 0.0}, "16": {"effect": 0.023245262410990838, "value": 1.0}, "17": {"effect": 0.024053945162641387, "value": 0.0}, "18": {"effect": -0.006064949808867602, "value": 0.0}, "19": {"effect": -0.0008579078270478823, "value": 0.0}, "20": {"effect": -0.024632237479584606, "value": 1.0}, "21": {"effect": 0.002085684476629677, "value": 0.0}, "22": {"effect": -0.0010005319995239784, "value": 0.0}, "23": {"effect": 0.00035832826434626535, "value": 0.0}, "24": {"effect": -0.002517691829354971, "value": 0.0}, "25": {"effect": 0.0027977355406877424, "value": 0.0}, "26": {"effect": 0.0005268308640605162, "value": 0.0}, "27": {"effect": -0.001102082704986414, "value": 0.0}, "28": {"effect": -0.001531154429690253, "value": 0.0}, "29": {"effect": -0.0018224083894996903, "value": 0.0}, "30": {"effect": -0.004070491927776308, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iXK8LSDTP34GXIL3KQDOF')
#   );
# </script>
# None

# %% [markdown]
# Obtain  explanations for instance 108 (Depressed)

# %%
shap.initjs()
shap_explanation(rf_grid, X_test, start_index=108, end_index=109)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Prediction: 1
# <div id='iTPB10NSYVVC0A6GJ6KSJ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49918035920487397, "outValue": 0.7286649641560855, "link": "identity", "featureNames": ["age", "people_in_the_household", "annual_household_income", "macro_score", "mineral_score", "vitamin_score", "total_nutrient_score", "citizenship_status_citizen", "citizenship_status_not_citizen", "citizenship_status_unknown", "education_level_9-11th_grade", "education_level_college_graduate", "education_level_high_school", "education_level_less_than_9th_grade", "education_level_some_college", "education_level_unknown", "gender_female", "gender_male", "marital_status_divorced", "marital_status_living_with_partner", "marital_status_married", "marital_status_never_married", "marital_status_separated", "marital_status_unknown", "marital_status_widowed", "race_asian", "race_black", "race_hispanic", "race_mexican", "race_other_race", "race_white"], "features": {"0": {"effect": 0.033268872257147655, "value": 63.0}, "1": {"effect": -0.0005322087267311584, "value": 1.0}, "2": {"effect": 0.053031932988949766, "value": 2.0}, "3": {"effect": 0.005258405879872453, "value": 1.0}, "4": {"effect": -0.0033079715057094403, "value": 1.0}, "5": {"effect": 0.010841960275297853, "value": 0.0}, "6": {"effect": 0.01949631935160416, "value": 2.0}, "7": {"effect": 0.0013367850666176724, "value": 1.0}, "8": {"effect": 0.0016142257676801455, "value": 0.0}, "9": {"effect": -4.0413105226464993e-05, "value": 0.0}, "10": {"effect": -0.00483005720287374, "value": 0.0}, "11": {"effect": 0.017219346042586094, "value": 0.0}, "12": {"effect": -0.0004142724655354415, "value": 0.0}, "13": {"effect": 0.0371806980964602, "value": 1.0}, "14": {"effect": 0.0014604653752494853, "value": 0.0}, "15": {"effect": 0.001935449575456876, "value": 0.0}, "16": {"effect": 0.018908533578044343, "value": 1.0}, "17": {"effect": 0.017107300729303325, "value": 0.0}, "18": {"effect": -0.0035869322109313272, "value": 0.0}, "19": {"effect": -0.0007366940178707263, "value": 0.0}, "20": {"effect": 0.012154313159777216, "value": 0.0}, "21": {"effect": 0.0027031694262961625, "value": 0.0}, "22": {"effect": 0.0023886236979348318, "value": 1.0}, "23": {"effect": 0.0017053760040924837, "value": 0.0}, "24": {"effect": -0.0018256185851755061, "value": 0.0}, "25": {"effect": 0.006704594159824606, "value": 0.0}, "26": {"effect": 0.0008821093490068194, "value": 1.0}, "27": {"effect": -0.001192031417360189, "value": 0.0}, "28": {"effect": 0.0018538884127137813, "value": 0.0}, "29": {"effect": -0.00130700920276655, "value": 0.0}, "30": {"effect": 0.00020544419747607875, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iTPB10NSYVVC0A6GJ6KSJ')
#   );
# </script>
# None

# %% [markdown]
# ### LIME<a class="anchor" id="lime"></a>

# %% [markdown]
# Obtain local explanations for first 110 instances

# %%
lime_explanation(rf_grid, X_test, y_test, start_index=0, end_index=109)
# Out:
# <!-- http://127.0.0.1:7254/2555185513184/ -->
# <iframe src="http://127.0.0.1:7254/2555185513184/" width=100% height=800 frameBorder="0"></iframe>
